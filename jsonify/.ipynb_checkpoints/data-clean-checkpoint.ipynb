# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mf_df=pd.read_csv("data_csv/Mutual-Funds.csv")
etf_df=pd.read_csv("data_csv/ETFs.csv")
# Out:
# C:\Users\Nate\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (167,171) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mf_df.head()
# Out:
#   fund_symbol                                 fund_extended_name  \
# 0       AAAAX               DWS RREEF Real Assets Fund - Class A
# 1       AAADX               Aberdeen Income Builder Fund Class A
# 2       AAAGX             Thrivent Large Cap Growth Fund Class A
# 3       AAAIX  American Century Strategic Allocation: Aggress...
# 4       AAANX  Horizon Active Asset Allocation Fund Investor ...
#
#                     fund_family inception_date  \
# 0                           DWS     2007-07-29
# 1                      Aberdeen     2011-12-29
# 2                Thrivent Funds     1999-10-28
# 3  American Century Investments     2000-07-31
# 4           Horizon Investments     2012-01-30
#
#                          category  rating  return_rating  risk_rating  \
# 0                World Allocation     3.0            3.0          3.0
# 1  Allocation - 50% to 70% Equity     4.0            5.0          5.0
# 2                    Large Growth     3.0            3.0          4.0
# 3  Allocation - 70% to 85% Equity     4.0            4.0          3.0
# 4             Tactical Allocation     3.0            4.0          5.0
#
#                                  investment_strategy investment_type  ...  \
# 0  The investment seeks total return in excess of...           Blend  ...
# 1  The investment seeks income; long-term growth ...           Blend  ...
# 2  The investment seeks long-term capital appreci...          Growth  ...
# 3  The investment seeks the highest level of tota...           Blend  ...
# 4  The investment seeks capital appreciation. The...           Blend  ...
#
#   fund_sharpe_ratio_5years category_sharpe_ratio_5years  \
# 0                     0.33                         0.00
# 1                     0.74                         0.01
# 2                     0.88                         0.01
# 3                     0.61                         0.00
# 4                     0.37                         0.00
#
#    fund_sharpe_ratio_10years  category_sharpe_ratio_10years  \
# 0                       0.24                           0.00
# 1                       0.89                           0.01
# 2                       0.93                           0.01
# 3                       0.73                           0.01
# 4                        NaN                           0.00
#
#    fund_treynor_ratio_3years  category_treynor_ratio_3years  \
# 0                       1.32                          -0.00
# 1                       6.82                           0.03
# 2                      16.87                           0.14
# 3                        3.7                           0.02
# 4                       0.86                           0.01
#
#    fund_treynor_ratio_5years  category_treynor_ratio_5years  \
# 0                       2.77                           0.03
# 1                       5.38                           0.05
# 2                      13.48                           0.13
# 3                       5.05                           0.04
# 4                       2.73                           0.04
#
#    fund_treynor_ratio_10years  category_treynor_ratio_10years
# 0                        1.91                            0.04
# 1                         7.1                            0.06
# 2                       13.03                            0.13
# 3                        5.87                            0.05
# 4                         NaN                            0.04
#
# [5 rows x 173 columns]

# %%
list(etf_df.columns)
# Out:
# ['fund_symbol',
#  'fund_extended_name',
#  'fund_family',
#  'inception_date',
#  'category',
#  'investment_strategy',
#  'investment_type',
#  'size_type',
#  'currency',
#  'fund_net_annual_expense_ratio',
#  'category_net_annual_expense_ratio',
#  'asset_stocks',
#  'asset_bonds',
#  'price_earnings_ratio',
#  'price_book_ratio',
#  'price_sales_ratio',
#  'price_cashflow_ratio',
#  'sector_basic_materials',
#  'sector_consumer_cyclical',
#  'sector_financial_services',
#  'sector_real_estate',
#  'sector_consumer_defensive',
#  'sector_healthcare',
#  'sector_utilities',
#  'sector_communication_services',
#  'sector_energy',
#  'sector_industrials',
#  'sector_technology',
#  'credit_us_government',
#  'credit_aaa',
#  'credit_aa',
#  'credit_a',
#  'credit_bbb',
#  'credit_bb',
#  'credit_b',
#  'credit_below_b',
#  'credit_other_ratings',
#  'net_asset_value',
#  'fund_yield',
#  'top10_holdings',
#  'fund_return_ytd',
#  'category_return_ytd',
#  'fund_return_1month',
#  'category_return_1month',
#  'fund_return_3months',
#  'category_return_3months',
#  'fund_return_1year',
#  'category_return_1year',
#  'fund_return_3years',
#  'category_return_3years',
#  'fund_return_5years',
#  'category_return_5years',
#  'fund_return_10years',
#  'category_return_10years',
#  'fund_return_2019',
#  'category_return_2019',
#  'fund_return_2018',
#  'category_return_2018',
#  'fund_return_2017',
#  'category_return_2017',
#  'fund_return_2016',
#  'category_return_2016',
#  'fund_return_2015',
#  'category_return_2015',
#  'fund_return_2014',
#  'category_return_2014',
#  'fund_return_2013',
#  'category_return_2013',
#  'fund_return_2012',
#  'category_return_2012',
#  'fund_return_2011',
#  'category_return_2011',
#  'fund_return_2010',
#  'category_return_2010',
#  'years_up',
#  'years_down',
#  'fund_alpha_3years',
#  'category_alpha_3years',
#  'fund_alpha_5years',
#  'category_alpha_5years',
#  'fund_alpha_10years',
#  'category_alpha_10years',
#  'fund_beta_3years',
#  'category_beta_3years',
#  'fund_beta_5years',
#  'category_beta_5years',
#  'fund_beta_10years',
#  'category_beta_10years',
#  'fund_mean_annual_return_3years',
#  'category_mean_annual_return_3years',
#  'fund_mean_annual_return_5years',
#  'category_mean_annual_return_5years',
#  'fund_mean_annual_return_10years',
#  'category_mean_annual_return_10years',
#  'fund_r_squared_3years',
#  'category_r_squared_3years',
#  'fund_r_squared_5years',
#  'category_r_squared_5years',
#  'fund_r_squared_10years',
#  'category_r_squared_10years',
#  'fund_standard_deviation_3years',
#  'category_standard_deviation_3years',
#  'fund_standard_deviation_5years',
#  'category_standard_deviation_5years',
#  'fund_standard_deviation_10years',
#  'category_standard_deviation_10years',
#  'fund_sharpe_ratio_3years',
#  'category_sharpe_ratio_3years',
#  'fund_sharpe_ratio_5years',
#  'category_sharpe_ratio_5years',
#  'fund_sharpe_ratio_10years',
#  'category_sharpe_ratio_10years',
#  'fund_treynor_ratio_3years',
#  'category_treynor_ratio_3years',
#  'fund_treynor_ratio_5years',
#  'category_treynor_ratio_5years',
#  'fund_treynor_ratio_10years',
#  'category_treynor_ratio_10years']

# %%
etf_df1= etf_df[[
 'fund_symbol',
 'fund_extended_name',
 'fund_family',
 'inception_date',
 'investment_strategy',
 'investment_type',
 'size_type',
 'currency',
 'top10_holdings',
 'net_asset_value',
 'fund_return_ytd',
 'fund_return_10years',
 'years_up',
 'years_down',
 'fund_mean_annual_return_10years'
]]

etf_df_top100=etf_df1.nlargest(100,'fund_mean_annual_return_10years')
etf_df_top100
# Out:
#      fund_symbol                       fund_extended_name  \
# 1625         XBI                     SPDR S&P Biotech ETF
# 1402        SOXX           iShares PHLX Semiconductor ETF
# 1202         PSI       Invesco Dynamic Semiconductors ETF
# 1657         XSD               SPDR S&P Semiconductor ETF
# 1174        PNQI              Invesco NASDAQ Internet ETF
# ...          ...                                      ...
# 54          1557                   SPDR S&P 500 ETF Trust
# 438         EQWM           Invesco S&P MidCap Quality ETF
# 870         INAA  iShares MSCI North America ETF USD Dist
# 1090         NFO            Invesco Insider Sentiment ETF
# 1168         PJP      Invesco Dynamic Pharmaceuticals ETF
#
#                                    fund_family inception_date  \
# 1625         SPDR State Street Global Advisors     2006-01-31
# 1402                                   iShares     2001-07-10
# 1202                                   Invesco     2005-06-23
# 1657         SPDR State Street Global Advisors     2006-01-31
# 1174                                   Invesco     2008-06-12
# ...                                        ...            ...
# 54           SPDR State Street Global Advisors     1993-01-22
# 438                                    Invesco     2006-12-01
# 870   BlackRock Asset Management Ireland - ETF     2006-06-02
# 1090                                   Invesco     2006-09-21
# 1168                                   Invesco     2005-06-23
#
#                                     investment_strategy investment_type  \
# 1625  The investment seeks to provide investment res...          Growth
# 1402  The investment seeks to track the investment r...           Blend
# 1202  The investment seeks to track the investment r...          Growth
# 1657  The investment seeks to provide investment res...          Growth
# 1174  The investment seeks to track the investment r...          Growth
# ...                                                 ...             ...
# 54    The investment seeks to provide investment res...           Blend
# 438   The investment seeks to track the investment r...          Growth
# 870   The fund is an exchange traded fund (ETF) that...           Blend
# 1090  The investment seeks to track the investment r...           Blend
# 1168  The investment seeks to track the investment r...           Value
#
#      size_type currency                                     top10_holdings  \
# 1625     Small      USD  Arrowhead Pharmaceuticals Inc: 1.64, Mirati Th...
# 1402     Large      USD  Qualcomm Inc: 8.29, Texas Instruments Inc: 8.1...
# 1202    Medium      USD  Skyworks Solutions Inc: 5.06, Lam Research Cor...
# 1657    Medium      USD  SunPower Corp: 4.06, Inphi Corp: 3.65, Monolit...
# 1174     Large      USD  Alibaba Group Holding Ltd ADR: 8.77, Alphabet ...
# ...        ...      ...                                                ...
# 54       Large      USD  Microsoft Corp: 5.52, Apple Inc: 5.24, Amazon....
# 438     Medium      USD  FactSet Research Systems Inc: 3.34, IDEX Corp:...
# 870      Large      USD  Apple Inc: 3.35, Microsoft Corp: 3.14, Amazon....
# 1090    Medium      USD  Fair Isaac Corp: 1.25, TransDigm Group Inc: 1....
# 1168    Medium      USD  Abbott Laboratories: 5.01, Endo International ...
#
#       net_asset_value  fund_return_ytd  fund_return_10years  years_up  \
# 1625     5.330000e+09            18.68                19.34        10
# 1402     3.610000e+09            22.80                21.24        11
# 1202     2.764200e+08            19.89                19.45        10
# 1657     5.730000e+08            25.59                19.29         9
# 1174     9.096100e+08            44.82                19.47         8
# ...               ...              ...                  ...       ...
# 54       2.706300e+11            -4.87                13.04        21
# 438      2.496000e+07            16.93                12.86         8
# 870      2.080000e+09             2.03                13.13         8
# 1090     8.113000e+07             2.14                12.72         9
# 1168     3.107400e+08            -3.73                12.37        11
#
#       years_down  fund_mean_annual_return_10years
# 1625           3                             1.83
# 1402           7                             1.79
# 1202           4                             1.70
# 1657           4                             1.69
# 1174           3                             1.64
# ...          ...                              ...
# 54             5                             1.10
# 438            4                             1.10
# 870            3                             1.10
# 1090           4                             1.10
# 1168           3                             1.10
#
# [100 rows x 15 columns]

# %%
list(mf_df.columns)
# Out:
# ['fund_symbol',
#  'fund_extended_name',
#  'fund_family',
#  'inception_date',
#  'category',
#  'rating',
#  'return_rating',
#  'risk_rating',
#  'investment_strategy',
#  'investment_type',
#  'size_type',
#  'currency',
#  'fund_net_annual_expense_ratio',
#  'category_net_annual_expense_ratio',
#  'asset_cash',
#  'asset_stocks',
#  'asset_bonds',
#  'asset_others',
#  'asset_preferred',
#  'asset_convertable',
#  'price_earnings_ratio',
#  'price_book_ratio',
#  'price_sales_ratio',
#  'price_cashflow_ratio',
#  'median_market_cap',
#  'sector_basic_materials',
#  'sector_consumer_cyclical',
#  'sector_financial_services',
#  'sector_real_estate',
#  'sector_consumer_defensive',
#  'sector_healthcare',
#  'sector_utilities',
#  'sector_communication_services',
#  'sector_energy',
#  'sector_industrials',
#  'sector_technology',
#  'bond_maturity',
#  'bond_duration',
#  'credit_us_government',
#  'credit_aaa',
#  'credit_aa',
#  'credit_a',
#  'credit_bbb',
#  'credit_bb',
#  'credit_b',
#  'credit_below_b',
#  'credit_other_ratings',
#  'net_asset_value',
#  'fund_yield',
#  'top10_holdings',
#  'fund_return_ytd',
#  'category_return_ytd',
#  'fund_return_1month',
#  'category_return_1month',
#  'fund_return_3months',
#  'category_return_3months',
#  'fund_return_1year',
#  'category_return_1year',
#  'fund_return_3years',
#  'category_return_3years',
#  'fund_return_5years',
#  'category_return_5years',
#  'fund_return_10years',
#  'category_return_10years',
#  'fund_return_2019',
#  'category_return_2019',
#  'fund_return_2018',
#  'category_return_2018',
#  'fund_return_2017',
#  'category_return_2017',
#  'fund_return_2016',
#  'category_return_2016',
#  'fund_return_2015',
#  'category_return_2015',
#  'fund_return_2014',
#  'category_return_2014',
#  'fund_return_2013',
#  'category_return_2013',
#  'fund_return_2012',
#  'category_return_2012',
#  'fund_return_2011',
#  'category_return_2011',
#  'fund_return_2010',
#  'category_return_2010',
#  'years_up',
#  'years_down',
#  'fund_return_2020_q3',
#  'fund_return_2020_q2',
#  'fund_return_2020_q1',
#  'fund_return_2019_q4',
#  'fund_return_2019_q3',
#  'fund_return_2019_q2',
#  'fund_return_2019_q1',
#  'fund_return_2018_q4',
#  'fund_return_2018_q3',
#  'fund_return_2018_q2',
#  'fund_return_2018_q1',
#  'fund_return_2017_q4',
#  'fund_return_2017_q3',
#  'fund_return_2017_q2',
#  'fund_return_2017_q1',
#  'fund_return_2016_q4',
#  'fund_return_2016_q3',
#  'fund_return_2016_q2',
#  'fund_return_2016_q1',
#  'fund_return_2015_q4',
#  'fund_return_2015_q3',
#  'fund_return_2015_q2',
#  'fund_return_2015_q1',
#  'fund_return_2014_q4',
#  'fund_return_2014_q3',
#  'fund_return_2014_q2',
#  'fund_return_2014_q1',
#  'fund_return_2013_q4',
#  'fund_return_2013_q3',
#  'fund_return_2013_q2',
#  'fund_return_2013_q1',
#  'fund_return_2012_q4',
#  'fund_return_2012_q3',
#  'fund_return_2012_q2',
#  'fund_return_2012_q1',
#  'fund_return_2011_q4',
#  'fund_return_2011_q3',
#  'fund_return_2011_q2',
#  'fund_return_2011_q1',
#  'fund_return_2010_q4',
#  'fund_return_2010_q3',
#  'fund_return_2010_q2',
#  'fund_return_2010_q1',
#  'quarters_up',
#  'quarters_down',
#  'fund_alpha_3years',
#  'category_alpha_3years',
#  'fund_alpha_5years',
#  'category_alpha_5years',
#  'fund_alpha_10years',
#  'category_alpha_10years',
#  'fund_beta_3years',
#  'category_beta_3years',
#  'fund_beta_5years',
#  'category_beta_5years',
#  'fund_beta_10years',
#  'category_beta_10years',
#  'fund_mean_annual_return_3years',
#  'category_mean_annual_return_3years',
#  'fund_mean_annual_return_5years',
#  'category_mean_annual_return_5years',
#  'fund_mean_annual_return_10years',
#  'category_mean_annual_return_10years',
#  'fund_r_squared_3years',
#  'category_r_squared_3years',
#  'fund_r_squared_5years',
#  'category_r_squared_5years',
#  'fund_r_squared_10years',
#  'category_r_squared_10years',
#  'fund_standard_deviation_3years',
#  'category_standard_deviation_3years',
#  'fund_standard_deviation_5years',
#  'category_standard_deviation_5years',
#  'fund_standard_deviation_10years',
#  'category_standard_deviation_10years',
#  'fund_sharpe_ratio_3years',
#  'category_sharpe_ratio_3years',
#  'fund_sharpe_ratio_5years',
#  'category_sharpe_ratio_5years',
#  'fund_sharpe_ratio_10years',
#  'category_sharpe_ratio_10years',
#  'fund_treynor_ratio_3years',
#  'category_treynor_ratio_3years',
#  'fund_treynor_ratio_5years',
#  'category_treynor_ratio_5years',
#  'fund_treynor_ratio_10years',
#  'category_treynor_ratio_10years']

# %%
mf_df1=mf_df[[
 'fund_symbol',
 'fund_extended_name',
 'fund_family',
 'inception_date',
 'rating',
 'return_rating',
 'risk_rating',
 'investment_strategy',
 'investment_type',
 'size_type',
 'currency',
 'years_up',
 'years_down',
 'net_asset_value',
 'top10_holdings',
 'fund_return_ytd',
 'fund_return_10years',
 'fund_mean_annual_return_10years',    
]]

# %%
mf_df_top100=mf_df1.nlargest(100, 'fund_mean_annual_return_10years')
mf_df_top100
# Out:
#       fund_symbol                                 fund_extended_name  \
# 4838        DXQLX  Direxion Monthly NASDAQ-100 Bull 2X Fund Inves...
# 20549       RYVLX          Rydex NASDAQ-100 2x Strategy Fund Class A
# 20554       RYVYX          Rydex NASDAQ-100 2x Strategy Fund Class H
# 23351       UOPIX       ProFunds UltraNASDAQ-100 Fund Investor Class
# 20381       RYCCX          Rydex NASDAQ-100 2x Strategy Fund Class C
# ...           ...                                                ...
# 7442        FSMEX  Fidelity Select Medical Technology and Devices...
# 11427       JGLTX  Janus Henderson VIT Global Technology and Inno...
# 14856       MPEGX  Morgan Stanley Institutional Fund Trust Discov...
# 3858        CTCAX     Columbia Global Technology Growth Fund Class A
# 4193        DFCIX              Delaware Smid Cap Growth Fund Class A
#
#                        fund_family inception_date  rating  return_rating  \
# 4838                Direxion Funds     2006-04-30     3.0            4.0
# 20549                  Rydex Funds     2004-08-31     3.0            5.0
# 20554                  Rydex Funds     2000-05-23     2.0            5.0
# 23351                     ProFunds     1997-11-30     2.0            5.0
# 20381                  Rydex Funds     2000-11-19     2.0            5.0
# ...                            ...            ...     ...            ...
# 7442          Fidelity Investments     1998-04-27     5.0            5.0
# 11427              Janus Henderson     2000-01-17     5.0            4.0
# 14856               Morgan Stanley     1990-03-29     5.0            5.0
# 3858                      Columbia     2002-10-31     4.0            4.0
# 4193   Delaware Funds by Macquarie     1986-03-26     5.0            5.0
#
#        risk_rating                                investment_strategy  \
# 4838           5.0  The investment seeks monthly investment result...
# 20549          5.0  The investment seeks to provide investment res...
# 20554          5.0  The investment seeks to provide investment res...
# 23351          5.0  The investment seeks daily investment results,...
# 20381          5.0  The investment seeks to provide investment res...
# ...            ...                                                ...
# 7442           3.0  The investment seeks capital appreciation. The...
# 11427          2.0  The investment seeks long-term growth of capit...
# 14856          5.0  The investment seeks long-term capital growth....
# 3858           3.0  The investment seeks capital appreciation. The...
# 4193           5.0  The investment seeks long-term capital appreci...
#
#       investment_type size_type currency  years_up  years_down  \
# 4838           Growth     Large      USD      11.0         2.0
# 20549          Growth     Large      USD      11.0         4.0
# 20554          Growth     Large      USD      13.0         6.0
# 23351          Growth     Large      USD      15.0         7.0
# 20381          Growth     Large      USD      13.0         6.0
# ...               ...       ...      ...       ...         ...
# 7442           Growth     Large      USD      18.0         3.0
# 11427          Growth     Large      USD      15.0         4.0
# 14856          Growth     Large      USD      21.0         8.0
# 3858           Growth     Large      USD      14.0         3.0
# 4193           Growth    Medium      USD      26.0         7.0
#
#        net_asset_value                                     top10_holdings  \
# 4838      2.975100e+08  197052NDXML12032020: 74.23, 197052NDXCS1210202...
# 20549     5.561100e+08  Apple Inc: 10.04, Microsoft Corp: 9.80, Amazon...
# 20554     5.561100e+08  Apple Inc: 10.04, Microsoft Corp: 9.80, Amazon...
# 23351     6.246300e+08  Soc 0.035% , 8/3/2020: 15.12, E-mini Nasdaq 10...
# 20381     5.561100e+08  Apple Inc: 10.04, Microsoft Corp: 9.80, Amazon...
# ...                ...                                                ...
# 7442      7.390000e+09  Thermo Fisher Scientific Inc: 12.07, Danaher C...
# 11427     6.886800e+08  Microsoft Corp: 9.38, Apple Inc: 7.12, Amazon....
# 14856     3.300000e+09  Shopify Inc A: 6.70, Spotify Technology SA: 5....
# 3858      2.310000e+09  Apple Inc: 9.27, Microsoft Corp: 7.97, Amazon....
# 4193      3.610000e+09  Exact Sciences Corp: 4.83, NovoCure Ltd: 4.43,...
#
#        fund_return_ytd  fund_return_10years  fund_mean_annual_return_10years
# 4838             49.89                34.73                             2.90
# 20549            39.52                32.79                             2.80
# 20554            39.52                32.78                             2.80
# 23351            38.38                32.61                             2.79
# 20381            38.65                31.78                             2.74
# ...                ...                  ...                              ...
# 7442             19.28                19.31                             1.58
# 11427            31.20                19.20                             1.58
# 14856            96.51                18.25                             1.58
# 3858             25.34                18.96                             1.57
# 4193             53.45                18.52                             1.57
#
# [100 rows x 18 columns]

# %%
etf_df_top100.dtypes
# Out:
# fund_symbol                         object
# fund_extended_name                  object
# fund_family                         object
# inception_date                      object
# investment_strategy                 object
# investment_type                     object
# size_type                           object
# currency                            object
# top10_holdings                      object
# net_asset_value                    float64
# fund_return_ytd                    float64
# fund_return_10years                float64
# years_up                             int64
# years_down                           int64
# fund_mean_annual_return_10years    float64
# dtype: object

# %%
mf_df_top100.dtypes
# Out:
# fund_symbol                         object
# fund_extended_name                  object
# fund_family                         object
# inception_date                      object
# rating                             float64
# return_rating                      float64
# risk_rating                        float64
# investment_strategy                 object
# investment_type                     object
# size_type                           object
# currency                            object
# years_up                           float64
# years_down                         float64
# net_asset_value                    float64
# top10_holdings                      object
# fund_return_ytd                    float64
# fund_return_10years                float64
# fund_mean_annual_return_10years    float64
# dtype: object

# %%
etf_df_top100.to_csv('data_csv/etf_df_top100.csv')

# %%
mf_df_top100.to_csv('data_csv/mf_df_top100.csv')
